# %%
import requests
import pandas as pd
import re

# %%
from nba_api.live.nba.endpoints import scoreboard
from nba_api.live.nba.endpoints import boxscore

# %%
# Today's Score Board
games = scoreboard.ScoreBoard()

# dictionary
games.get_dict()
# Out:
# {'meta': {'version': 1,
#   'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#   'time': '2023-03-22 11:37:08.378',
#   'code': 200},
#  'scoreboard': {'gameDate': '2023-03-22',
#   'leagueId': '00',
#   'leagueName': 'National Basketball Association',
#   'games': [{'gameId': '0022201092',
#     'gameCode': '20230322/PHXLAL',
#     'gameStatus': 2,
#     'gameStatusText': 'Q3 10:36',
#     'period': 3,
#     'gameClock': 'PT10M36.00S',
#     'gameTimeUTC': '2023-03-23T02:00:00Z',
#     'gameEt': '2023-03-22T22:00:00-04:00',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612747,
#      'teamName': 'Lakers',
#      'teamCity': 'Los Angeles',
#      'teamTricode': 'LAL',
#      'wins': 35,
#      'losses': 37,
#      'score': 62,
#      'seed': None,
#      'inBonus': '0',
#      'timeoutsRemaining': 5,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 23},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 36},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 3},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612756,
#      'teamName': 'Suns',
#      'teamCity': 'Phoenix',
#      'teamTricode': 'PHX',
#      'wins': 38,
#      'losses': 33,
#      'score': 57,
#      'seed': None,
#      'inBonus': '0',
#      'timeoutsRemaining': 5,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 5},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1630559,
#       'name': 'Austin Reaves',
#       'jerseyNum': '15',
#       'position': 'G',
#       'teamTricode': 'LAL',
#       'playerSlug': 'austin-reaves',
#       'points': 13,
#       'rebounds': 2,
#       'assists': 4},
#      'awayLeaders': {'personId': 101108,
#       'name': 'Chris Paul',
#       'jerseyNum': '3',
#       'position': 'G',
#       'teamTricode': 'PHX',
#       'playerSlug': 'chris-paul',
#       'points': 14,
#       'rebounds': 2,
#       'assists': 2}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201083',
#     'gameCode': '20230322/DENWAS',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-22T23:00:00Z',
#     'gameEt': '2023-03-22T19:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612764,
#      'teamName': 'Wizards',
#      'teamCity': 'Washington',
#      'teamTricode': 'WAS',
#      'wins': 32,
#      'losses': 41,
#      'score': 104,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 29},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 16},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 31}]},
#     'awayTeam': {'teamId': 1610612743,
#      'teamName': 'Nuggets',
#      'teamCity': 'Denver',
#      'teamTricode': 'DEN',
#      'wins': 49,
#      'losses': 24,
#      'score': 118,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 31},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 24},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 39},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 24}]},
#     'gameLeaders': {'homeLeaders': {'personId': 204001,
#       'name': 'Kristaps Porzingis',
#       'jerseyNum': '6',
#       'position': 'F-C',
#       'teamTricode': 'WAS',
#       'playerSlug': None,
#       'points': 25,
#       'rebounds': 3,
#       'assists': 2},
#      'awayLeaders': {'personId': 203999,
#       'name': 'Nikola Jokic',
#       'jerseyNum': '15',
#       'position': 'C',
#       'teamTricode': 'DEN',
#       'playerSlug': None,
#       'points': 31,
#       'rebounds': 12,
#       'assists': 7}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201084',
#     'gameCode': '20230322/NYKMIA',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-22T23:30:00Z',
#     'gameEt': '2023-03-22T19:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612748,
#      'teamName': 'Heat',
#      'teamCity': 'Miami',
#      'teamTricode': 'MIA',
#      'wins': 40,
#      'losses': 34,
#      'score': 127,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 31},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 33},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 35}]},
#     'awayTeam': {'teamId': 1610612752,
#      'teamName': 'Knicks',
#      'teamCity': 'New York',
#      'teamTricode': 'NYK',
#      'wins': 42,
#      'losses': 32,
#      'score': 120,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 32},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 29},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 25},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 34}]},
#     'gameLeaders': {'homeLeaders': {'personId': 202710,
#       'name': 'Jimmy Butler',
#       'jerseyNum': '22',
#       'position': 'F',
#       'teamTricode': 'MIA',
#       'playerSlug': None,
#       'points': 35,
#       'rebounds': 4,
#       'assists': 9},
#      'awayLeaders': {'personId': 1629628,
#       'name': 'RJ Barrett',
#       'jerseyNum': '9',
#       'position': 'F-G',
#       'teamTricode': 'NYK',
#       'playerSlug': None,
#       'points': 26,
#       'rebounds': 6,
#       'assists': 5}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201085',
#     'gameCode': '20230322/INDTOR',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-22T23:30:00Z',
#     'gameEt': '2023-03-22T19:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612761,
#      'teamName': 'Raptors',
#      'teamCity': 'Toronto',
#      'teamTricode': 'TOR',
#      'wins': 35,
#      'losses': 38,
#      'score': 114,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 36}]},
#     'awayTeam': {'teamId': 1610612754,
#      'teamName': 'Pacers',
#      'teamCity': 'Indiana',
#      'teamTricode': 'IND',
#      'wins': 33,
#      'losses': 40,
#      'score': 118,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 36},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 22},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 25},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 35}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1627783,
#       'name': 'Pascal Siakam',
#       'jerseyNum': '43',
#       'position': 'F',
#       'teamTricode': 'TOR',
#       'playerSlug': None,
#       'points': 31,
#       'rebounds': 10,
#       'assists': 7},
#      'awayLeaders': {'personId': 1629614,
#       'name': 'Andrew Nembhard',
#       'jerseyNum': '2',
#       'position': 'G-F',
#       'teamTricode': 'IND',
#       'playerSlug': None,
#       'points': 25,
#       'rebounds': 2,
#       'assists': 10}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201086',
#     'gameCode': '20230322/GSWDAL',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-22T23:30:00Z',
#     'gameEt': '2023-03-22T19:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612742,
#      'teamName': 'Mavericks',
#      'teamCity': 'Dallas',
#      'teamTricode': 'DAL',
#      'wins': 36,
#      'losses': 37,
#      'score': 125,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 33},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 30},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 30},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 32}]},
#     'awayTeam': {'teamId': 1610612744,
#      'teamName': 'Warriors',
#      'teamCity': 'Golden State',
#      'teamTricode': 'GSW',
#      'wins': 38,
#      'losses': 36,
#      'score': 127,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 30},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 35},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 31},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 31}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1629029,
#       'name': 'Luka Doncic',
#       'jerseyNum': '77',
#       'position': 'F-G',
#       'teamTricode': 'DAL',
#       'playerSlug': None,
#       'points': 30,
#       'rebounds': 7,
#       'assists': 17},
#      'awayLeaders': {'personId': 201939,
#       'name': 'Stephen Curry',
#       'jerseyNum': '30',
#       'position': 'G',
#       'teamTricode': 'GSW',
#       'playerSlug': None,
#       'points': 20,
#       'rebounds': 5,
#       'assists': 13}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201087',
#     'gameCode': '20230322/PHICHI',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-23T00:00:00Z',
#     'gameEt': '2023-03-22T20:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612741,
#      'teamName': 'Bulls',
#      'teamCity': 'Chicago',
#      'teamTricode': 'CHI',
#      'wins': 34,
#      'losses': 38,
#      'score': 91,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 23},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 25},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 15}]},
#     'awayTeam': {'teamId': 1610612755,
#      'teamName': '76ers',
#      'teamCity': 'Philadelphia',
#      'teamTricode': 'PHI',
#      'wins': 49,
#      'losses': 23,
#      'score': 116,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 36},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 40},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 20},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 20}]},
#     'gameLeaders': {'homeLeaders': {'personId': 203083,
#       'name': 'Andre Drummond',
#       'jerseyNum': '3',
#       'position': 'C',
#       'teamTricode': 'CHI',
#       'playerSlug': None,
#       'points': 13,
#       'rebounds': 12,
#       'assists': 1},
#      'awayLeaders': {'personId': 202699,
#       'name': 'Tobias Harris',
#       'jerseyNum': '12',
#       'position': 'F',
#       'teamTricode': 'PHI',
#       'playerSlug': None,
#       'points': 20,
#       'rebounds': 9,
#       'assists': 8}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201088',
#     'gameCode': '20230322/HOUMEM',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-23T00:00:00Z',
#     'gameEt': '2023-03-22T20:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612763,
#      'teamName': 'Grizzlies',
#      'teamCity': 'Memphis',
#      'teamTricode': 'MEM',
#      'wins': 45,
#      'losses': 27,
#      'score': 130,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 37},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 38},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 26},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 29}]},
#     'awayTeam': {'teamId': 1610612745,
#      'teamName': 'Rockets',
#      'teamCity': 'Houston',
#      'teamTricode': 'HOU',
#      'wins': 18,
#      'losses': 55,
#      'score': 125,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 34},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 30},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 32},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 29}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1628991,
#       'name': 'Jaren Jackson Jr.',
#       'jerseyNum': '13',
#       'position': 'F-C',
#       'teamTricode': 'MEM',
#       'playerSlug': None,
#       'points': 37,
#       'rebounds': 10,
#       'assists': 2},
#      'awayLeaders': {'personId': 1630224,
#       'name': 'Jalen Green',
#       'jerseyNum': '4',
#       'position': 'G',
#       'teamTricode': 'HOU',
#       'playerSlug': None,
#       'points': 32,
#       'rebounds': 3,
#       'assists': 3}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201089',
#     'gameCode': '20230322/SASMIL',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-23T00:00:00Z',
#     'gameEt': '2023-03-22T20:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612749,
#      'teamName': 'Bucks',
#      'teamCity': 'Milwaukee',
#      'teamTricode': 'MIL',
#      'wins': 52,
#      'losses': 20,
#      'score': 130,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 33},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 33},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 34},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 30}]},
#     'awayTeam': {'teamId': 1610612759,
#      'teamName': 'Spurs',
#      'teamCity': 'San Antonio',
#      'teamTricode': 'SAS',
#      'wins': 19,
#      'losses': 54,
#      'score': 94,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 23},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 21},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 22}]},
#     'gameLeaders': {'homeLeaders': {'personId': 203507,
#       'name': 'Giannis Antetokounmpo',
#       'jerseyNum': '34',
#       'position': 'F',
#       'teamTricode': 'MIL',
#       'playerSlug': None,
#       'points': 31,
#       'rebounds': 14,
#       'assists': 2},
#      'awayLeaders': {'personId': 1630170,
#       'name': 'Devin Vassell',
#       'jerseyNum': '24',
#       'position': 'G-F',
#       'teamTricode': 'SAS',
#       'playerSlug': None,
#       'points': 16,
#       'rebounds': 4,
#       'assists': 4}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201090',
#     'gameCode': '20230322/ATLMIN',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-23T00:00:00Z',
#     'gameEt': '2023-03-22T20:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612750,
#      'teamName': 'Timberwolves',
#      'teamCity': 'Minnesota',
#      'teamTricode': 'MIN',
#      'wins': 37,
#      'losses': 37,
#      'score': 125,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 39},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 28},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 27},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 31}]},
#     'awayTeam': {'teamId': 1610612737,
#      'teamName': 'Hawks',
#      'teamCity': 'Atlanta',
#      'teamTricode': 'ATL',
#      'wins': 36,
#      'losses': 37,
#      'score': 124,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 40},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 22},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 35},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 27}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1630183,
#       'name': 'Jaden McDaniels',
#       'jerseyNum': '3',
#       'position': 'F',
#       'teamTricode': 'MIN',
#       'playerSlug': None,
#       'points': 25,
#       'rebounds': 6,
#       'assists': 4},
#      'awayLeaders': {'personId': 1629027,
#       'name': 'Trae Young',
#       'jerseyNum': '11',
#       'position': 'G',
#       'teamTricode': 'ATL',
#       'playerSlug': None,
#       'points': 29,
#       'rebounds': 2,
#       'assists': 8}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022201091',
#     'gameCode': '20230322/PORUTA',
#     'gameStatus': 3,
#     'gameStatusText': 'Final',
#     'period': 4,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-23T01:00:00Z',
#     'gameEt': '2023-03-22T21:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'seriesConference': '',
#     'poRoundDesc': '',
#     'homeTeam': {'teamId': 1610612762,
#      'teamName': 'Jazz',
#      'teamCity': 'Utah',
#      'teamTricode': 'UTA',
#      'wins': 35,
#      'losses': 37,
#      'score': 115,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 34},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 22},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 32},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 27}]},
#     'awayTeam': {'teamId': 1610612757,
#      'teamName': 'Trail Blazers',
#      'teamCity': 'Portland',
#      'teamTricode': 'POR',
#      'wins': 32,
#      'losses': 40,
#      'score': 127,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 1,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 29},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 39},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 23},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 36}]},
#     'gameLeaders': {'homeLeaders': {'personId': 1628374,
#       'name': 'Lauri Markkanen',
#       'jerseyNum': '23',
#       'position': 'F-C',
#       'teamTricode': 'UTA',
#       'playerSlug': None,
#       'points': 40,
#       'rebounds': 12,
#       'assists': 3},
#      'awayLeaders': {'personId': 203081,
#       'name': 'Damian Lillard',
#       'jerseyNum': '0',
#       'position': 'G',
#       'teamTricode': 'POR',
#       'playerSlug': None,
#       'points': 30,
#       'rebounds': 7,
#       'assists': 12}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}}]}}

# %% [markdown]
# ### Get list of active games

# %%
games = scoreboard.ScoreBoard()

# dictionary
board = games.get_dict()

all_games = board['scoreboard']['games']
active_games = []

for game in all_games:
    if game['gameStatus'] == 2:
        active_games.append(game)

active_games
# Out:
# [{'gameId': '0022201092',
#   'gameCode': '20230322/PHXLAL',
#   'gameStatus': 2,
#   'gameStatusText': 'Q3 10:36',
#   'period': 3,
#   'gameClock': 'PT10M36.00S',
#   'gameTimeUTC': '2023-03-23T02:00:00Z',
#   'gameEt': '2023-03-22T22:00:00-04:00',
#   'regulationPeriods': 4,
#   'ifNecessary': False,
#   'seriesGameNumber': '',
#   'seriesText': '',
#   'seriesConference': '',
#   'poRoundDesc': '',
#   'homeTeam': {'teamId': 1610612747,
#    'teamName': 'Lakers',
#    'teamCity': 'Los Angeles',
#    'teamTricode': 'LAL',
#    'wins': 35,
#    'losses': 37,
#    'score': 62,
#    'seed': None,
#    'inBonus': '0',
#    'timeoutsRemaining': 5,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 23},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 36},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 3},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#   'awayTeam': {'teamId': 1610612756,
#    'teamName': 'Suns',
#    'teamCity': 'Phoenix',
#    'teamTricode': 'PHX',
#    'wins': 38,
#    'losses': 33,
#    'score': 57,
#    'seed': None,
#    'inBonus': '0',
#    'timeoutsRemaining': 5,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 26},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 26},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 5},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#   'gameLeaders': {'homeLeaders': {'personId': 1630559,
#     'name': 'Austin Reaves',
#     'jerseyNum': '15',
#     'position': 'G',
#     'teamTricode': 'LAL',
#     'playerSlug': 'austin-reaves',
#     'points': 13,
#     'rebounds': 2,
#     'assists': 4},
#    'awayLeaders': {'personId': 101108,
#     'name': 'Chris Paul',
#     'jerseyNum': '3',
#     'position': 'G',
#     'teamTricode': 'PHX',
#     'playerSlug': 'chris-paul',
#     'points': 14,
#     'rebounds': 2,
#     'assists': 2}},
#   'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}}]

# %%
boxscore.BoxScore('0022201092').get_dict()
# Out:
# {'meta': {'version': 1,
#   'code': 200,
#   'request': 'http://nba.cloud/games/0022201092/boxscore?Format=json',
#   'time': '2023-03-23 02:42:43.228950'},
#  'game': {'gameId': '0022201092',
#   'gameTimeLocal': '2023-03-22T19:00:00-07:00',
#   'gameTimeUTC': '2023-03-23T02:00:00Z',
#   'gameTimeHome': '2023-03-22T19:00:00-07:00',
#   'gameTimeAway': '2023-03-22T19:00:00-07:00',
#   'gameEt': '2023-03-22T22:00:00-04:00',
#   'duration': 143,
#   'gameCode': '20230322/PHXLAL',
#   'gameStatusText': 'Final',
#   'gameStatus': 3,
#   'regulationPeriods': 4,
#   'period': 4,
#   'gameClock': 'PT00M00.00S',
#   'attendance': 18435,
#   'sellout': '0',
#   'arena': {'arenaId': 1000069,
#    'arenaName': 'Crypto.com Arena',
#    'arenaCity': 'Los Angeles',
#    'arenaState': 'CA',
#    'arenaCountry': 'US',
#    'arenaTimezone': 'America/Los_Angeles'},
#   'officials': [{'personId': 1162,
#     'name': 'Scott Foster',
#     'nameI': 'S. Foster',
#     'firstName': 'Scott',
#     'familyName': 'Foster',
#     'jerseyNum': '48',
#     'assignment': 'OFFICIAL1'},
#    {'personId': 201245,
#     'name': 'Marat Kogut',
#     'nameI': 'M. Kogut',
#     'firstName': 'Marat',
#     'familyName': 'Kogut',
#     'jerseyNum': '32',
#     'assignment': 'OFFICIAL3'},
#    {'personId': 204058,
#     'name': 'Gediminas Petraitis',
#     'nameI': 'G. Petraitis',
#     'firstName': 'Gediminas',
#     'familyName': 'Petraitis',
#     'jerseyNum': '50',
#     'assignment': 'OFFICIAL2'}],
#   'homeTeam': {'teamId': 1610612747,
#    'teamName': 'Lakers',
#    'teamCity': 'Los Angeles',
#    'teamTricode': 'LAL',
#    'score': 122,
#    'inBonus': '1',
#    'timeoutsRemaining': 2,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 23},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 36},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 29},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 34}],
#    'players': [{'status': 'ACTIVE',
#      'order': 1,
#      'personId': 1628972,
#      'jerseyNum': '7',
#      'position': 'SF',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 0,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 6,
#       'fieldGoalsMade': 2,
#       'fieldGoalsPercentage': 0.333333333333333,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 3,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 2,
#       'freeThrowsMade': 1,
#       'freeThrowsPercentage': 0.5,
#       'minus': 54.0,
#       'minutes': 'PT25M00.00S',
#       'minutesCalculated': 'PT25M',
#       'plus': 65.0,
#       'plusMinusPoints': 11.0,
#       'points': 6,
#       'pointsFastBreak': 2,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 6,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 6,
#       'steals': 1,
#       'threePointersAttempted': 3,
#       'threePointersMade': 1,
#       'threePointersPercentage': 0.333333333333333,
#       'turnovers': 0,
#       'twoPointersAttempted': 3,
#       'twoPointersMade': 1,
#       'twoPointersPercentage': 0.333333333333333},
#      'name': 'Troy Brown Jr.',
#      'nameI': 'T. Brown Jr.',
#      'firstName': 'Troy',
#      'familyName': 'Brown Jr.'},
#     {'status': 'ACTIVE',
#      'order': 2,
#      'personId': 1629020,
#      'jerseyNum': '2',
#      'position': 'PF',
#      'starter': '1',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 5,
#       'fieldGoalsMade': 5,
#       'fieldGoalsPercentage': 1.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 5,
#       'foulsPersonal': 5,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 3,
#       'freeThrowsMade': 3,
#       'freeThrowsPercentage': 1.0,
#       'minus': 61.0,
#       'minutes': 'PT26M11.00S',
#       'minutesCalculated': 'PT26M',
#       'plus': 69.0,
#       'plusMinusPoints': 8.0,
#       'points': 13,
#       'pointsFastBreak': 5,
#       'pointsInThePaint': 10,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 2,
#       'reboundsOffensive': 2,
#       'reboundsTotal': 4,
#       'steals': 1,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 1,
#       'twoPointersAttempted': 5,
#       'twoPointersMade': 5,
#       'twoPointersPercentage': 1.0},
#      'name': 'Jarred Vanderbilt',
#      'nameI': 'J. Vanderbilt',
#      'firstName': 'Jarred',
#      'familyName': 'Vanderbilt'},
#     {'status': 'ACTIVE',
#      'order': 3,
#      'personId': 203076,
#      'jerseyNum': '3',
#      'position': 'C',
#      'starter': '1',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 5,
#       'blocks': 0,
#       'blocksReceived': 2,
#       'fieldGoalsAttempted': 18,
#       'fieldGoalsMade': 10,
#       'fieldGoalsPercentage': 0.555555555555556,
#       'foulsOffensive': 1,
#       'foulsDrawn': 6,
#       'foulsPersonal': 4,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 10,
#       'freeThrowsMade': 7,
#       'freeThrowsPercentage': 0.7,
#       'minus': 85.0,
#       'minutes': 'PT38M17.08S',
#       'minutesCalculated': 'PT38M',
#       'plus': 98.0,
#       'plusMinusPoints': 13.0,
#       'points': 27,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 14,
#       'pointsSecondChance': 2,
#       'reboundsDefensive': 8,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 9,
#       'steals': 1,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 1,
#       'twoPointersAttempted': 18,
#       'twoPointersMade': 10,
#       'twoPointersPercentage': 0.555555555555556},
#      'name': 'Anthony Davis',
#      'nameI': 'A. Davis',
#      'firstName': 'Anthony',
#      'familyName': 'Davis'},
#     {'status': 'ACTIVE',
#      'order': 4,
#      'personId': 1630559,
#      'jerseyNum': '15',
#      'position': 'SG',
#      'starter': '1',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 11,
#       'blocks': 0,
#       'blocksReceived': 2,
#       'fieldGoalsAttempted': 10,
#       'fieldGoalsMade': 6,
#       'fieldGoalsPercentage': 0.6,
#       'foulsOffensive': 0,
#       'foulsDrawn': 7,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 13,
#       'freeThrowsMade': 12,
#       'freeThrowsPercentage': 0.923076923076923,
#       'minus': 88.0,
#       'minutes': 'PT38M48.00S',
#       'minutesCalculated': 'PT39M',
#       'plus': 106.0,
#       'plusMinusPoints': 18.0,
#       'points': 25,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 8,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 4,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 4,
#       'steals': 1,
#       'threePointersAttempted': 1,
#       'threePointersMade': 1,
#       'threePointersPercentage': 1.0,
#       'turnovers': 2,
#       'twoPointersAttempted': 9,
#       'twoPointersMade': 5,
#       'twoPointersPercentage': 0.555555555555556},
#      'name': 'Austin Reaves',
#      'nameI': 'A. Reaves',
#      'firstName': 'Austin',
#      'familyName': 'Reaves'},
#     {'status': 'ACTIVE',
#      'order': 5,
#      'personId': 1626156,
#      'jerseyNum': '1',
#      'position': 'PG',
#      'starter': '1',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 6,
#       'blocks': 2,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 13,
#       'fieldGoalsMade': 9,
#       'fieldGoalsPercentage': 0.692307692307692,
#       'foulsOffensive': 0,
#       'foulsDrawn': 4,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 7,
#       'freeThrowsMade': 5,
#       'freeThrowsPercentage': 0.714285714285714,
#       'minus': 81.0,
#       'minutes': 'PT34M04.96S',
#       'minutesCalculated': 'PT34M',
#       'plus': 94.0,
#       'plusMinusPoints': 13.0,
#       'points': 26,
#       'pointsFastBreak': 4,
#       'pointsInThePaint': 10,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 1,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 1,
#       'steals': 1,
#       'threePointersAttempted': 6,
#       'threePointersMade': 3,
#       'threePointersPercentage': 0.5,
#       'turnovers': 4,
#       'twoPointersAttempted': 7,
#       'twoPointersMade': 6,
#       'twoPointersPercentage': 0.857142857142857},
#      'name': "D'Angelo Russell",
#      'nameI': 'D. Russell',
#      'firstName': "D'Angelo",
#      'familyName': 'Russell'},
#     {'status': 'ACTIVE',
#      'order': 6,
#      'personId': 1627736,
#      'jerseyNum': '5',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 6,
#       'fieldGoalsMade': 2,
#       'fieldGoalsPercentage': 0.333333333333333,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 49.0,
#       'minutes': 'PT19M45.00S',
#       'minutesCalculated': 'PT20M',
#       'plus': 41.0,
#       'plusMinusPoints': -8.0,
#       'points': 6,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 4,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 4,
#       'steals': 0,
#       'threePointersAttempted': 5,
#       'threePointersMade': 2,
#       'threePointersPercentage': 0.4,
#       'turnovers': 1,
#       'twoPointersAttempted': 1,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Malik Beasley',
#      'nameI': 'M. Beasley',
#      'firstName': 'Malik',
#      'familyName': 'Beasley'},
#     {'status': 'ACTIVE',
#      'order': 7,
#      'personId': 1629117,
#      'jerseyNum': '35',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 2,
#       'fieldGoalsMade': 2,
#       'fieldGoalsPercentage': 1.0,
#       'foulsOffensive': 1,
#       'foulsDrawn': 3,
#       'foulsPersonal': 3,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 5,
#       'freeThrowsMade': 2,
#       'freeThrowsPercentage': 0.4,
#       'minus': 37.0,
#       'minutes': 'PT16M04.92S',
#       'minutesCalculated': 'PT16M',
#       'plus': 34.0,
#       'plusMinusPoints': -3.0,
#       'points': 6,
#       'pointsFastBreak': 2,
#       'pointsInThePaint': 4,
#       'pointsSecondChance': 1,
#       'reboundsDefensive': 1,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 2,
#       'steals': 2,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 3,
#       'twoPointersAttempted': 2,
#       'twoPointersMade': 2,
#       'twoPointersPercentage': 1.0},
#      'name': 'Wenyen Gabriel',
#      'nameI': 'W. Gabriel',
#      'firstName': 'Wenyen',
#      'familyName': 'Gabriel'},
#     {'status': 'ACTIVE',
#      'order': 8,
#      'personId': 203471,
#      'jerseyNum': '17',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 0,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 7,
#       'fieldGoalsMade': 3,
#       'fieldGoalsPercentage': 0.428571428571429,
#       'foulsOffensive': 0,
#       'foulsDrawn': 4,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 6,
#       'freeThrowsMade': 6,
#       'freeThrowsPercentage': 1.0,
#       'minus': 66.0,
#       'minutes': 'PT28M54.04S',
#       'minutesCalculated': 'PT29M',
#       'plus': 70.0,
#       'plusMinusPoints': 4.0,
#       'points': 13,
#       'pointsFastBreak': 4,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 3,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 4,
#       'steals': 0,
#       'threePointersAttempted': 1,
#       'threePointersMade': 1,
#       'threePointersPercentage': 1.0,
#       'turnovers': 1,
#       'twoPointersAttempted': 6,
#       'twoPointersMade': 2,
#       'twoPointersPercentage': 0.333333333333333},
#      'name': 'Dennis Schroder',
#      'nameI': 'D. Schroder',
#      'firstName': 'Dennis',
#      'familyName': 'Schroder'},
#     {'status': 'ACTIVE',
#      'order': 9,
#      'personId': 1629060,
#      'jerseyNum': '28',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 3,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 1,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 34.0,
#       'minutes': 'PT12M55.00S',
#       'minutesCalculated': 'PT13M',
#       'plus': 33.0,
#       'plusMinusPoints': -1.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 2,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 2,
#       'steals': 0,
#       'threePointersAttempted': 1,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 2,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Rui Hachimura',
#      'nameI': 'R. Hachimura',
#      'firstName': 'Rui',
#      'familyName': 'Hachimura'},
#     {'status': 'ACTIVE',
#      'order': 10,
#      'personId': 1631108,
#      'jerseyNum': '10',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Max Christie',
#      'nameI': 'M. Christie',
#      'firstName': 'Max',
#      'familyName': 'Christie'},
#     {'status': 'ACTIVE',
#      'order': 11,
#      'personId': 1628432,
#      'jerseyNum': '11',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Davon Reed',
#      'nameI': 'D. Reed',
#      'firstName': 'Davon',
#      'familyName': 'Reed'},
#     {'status': 'ACTIVE',
#      'order': 12,
#      'personId': 1629022,
#      'jerseyNum': '4',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Lonnie Walker IV',
#      'nameI': 'L. Walker IV',
#      'firstName': 'Lonnie',
#      'familyName': 'Walker IV'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Left Ankle; Sprain',
#      'order': 13,
#      'personId': 1628964,
#      'jerseyNum': '12',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Mo Bamba',
#      'nameI': 'M. Bamba',
#      'firstName': 'Mo',
#      'familyName': 'Bamba'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Right Foot; Soreness',
#      'order': 14,
#      'personId': 2544,
#      'jerseyNum': '6',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'LeBron James',
#      'nameI': 'L. James',
#      'firstName': 'LeBron',
#      'familyName': 'James'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_GLEAGUE_TWOWAY',
#      'order': 15,
#      'personId': 1630590,
#      'jerseyNum': '14',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Scotty Pippen Jr.',
#      'nameI': 'S. Pippen Jr.',
#      'firstName': 'Scotty',
#      'familyName': 'Pippen Jr.'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_GLEAGUE_TWOWAY',
#      'order': 16,
#      'personId': 1631306,
#      'jerseyNum': '20',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Cole Swider',
#      'nameI': 'C. Swider',
#      'firstName': 'Cole',
#      'familyName': 'Swider'}],
#    'statistics': {'assists': 27,
#     'assistsTurnoverRatio': 1.8,
#     'benchPoints': 25,
#     'biggestLead': 12,
#     'biggestLeadScore': '46-58',
#     'biggestScoringRun': 12,
#     'biggestScoringRunScore': '46-58',
#     'blocks': 2,
#     'blocksReceived': 6,
#     'fastBreakPointsAttempted': 8,
#     'fastBreakPointsMade': 5,
#     'fastBreakPointsPercentage': 0.625,
#     'fieldGoalsAttempted': 70,
#     'fieldGoalsEffectiveAdjusted': 0.614285714285714,
#     'fieldGoalsMade': 39,
#     'fieldGoalsPercentage': 0.557142857142857,
#     'foulsOffensive': 2,
#     'foulsDrawn': 31,
#     'foulsPersonal': 20,
#     'foulsTeam': 18,
#     'foulsTechnical': 0,
#     'foulsTeamTechnical': 0,
#     'freeThrowsAttempted': 46,
#     'freeThrowsMade': 36,
#     'freeThrowsPercentage': 0.7826086956521741,
#     'leadChanges': 6,
#     'minutes': 'PT240M00.00S',
#     'minutesCalculated': 'PT240M',
#     'points': 122,
#     'pointsAgainst': 111,
#     'pointsFastBreak': 17,
#     'pointsFromTurnovers': 27,
#     'pointsInThePaint': 50,
#     'pointsInThePaintAttempted': 40,
#     'pointsInThePaintMade': 25,
#     'pointsInThePaintPercentage': 0.625,
#     'pointsSecondChance': 3,
#     'reboundsDefensive': 31,
#     'reboundsOffensive': 5,
#     'reboundsPersonal': 36,
#     'reboundsTeam': 12,
#     'reboundsTeamDefensive': 4,
#     'reboundsTeamOffensive': 8,
#     'reboundsTotal': 48,
#     'secondChancePointsAttempted': 3,
#     'secondChancePointsMade': 1,
#     'secondChancePointsPercentage': 0.333333333333333,
#     'steals': 7,
#     'threePointersAttempted': 17,
#     'threePointersMade': 8,
#     'threePointersPercentage': 0.470588235294118,
#     'timeLeading': 'PT35M18.97S',
#     'timesTied': 7,
#     'trueShootingAttempts': 90.24,
#     'trueShootingPercentage': 0.675975177304965,
#     'turnovers': 13,
#     'turnoversTeam': 2,
#     'turnoversTotal': 15,
#     'twoPointersAttempted': 53,
#     'twoPointersMade': 31,
#     'twoPointersPercentage': 0.584905660377358}},
#   'awayTeam': {'teamId': 1610612756,
#    'teamName': 'Suns',
#    'teamCity': 'Phoenix',
#    'teamTricode': 'PHX',
#    'score': 111,
#    'inBonus': '0',
#    'timeoutsRemaining': 2,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 26},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 26},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 33},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 26}],
#    'players': [{'status': 'ACTIVE',
#      'order': 1,
#      'personId': 1629006,
#      'jerseyNum': '2',
#      'position': 'SF',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 1,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 5,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 4,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 6,
#       'freeThrowsMade': 5,
#       'freeThrowsPercentage': 0.833333333333334,
#       'minus': 50.0,
#       'minutes': 'PT19M53.08S',
#       'minutesCalculated': 'PT20M',
#       'plus': 47.0,
#       'plusMinusPoints': -3.0,
#       'points': 5,
#       'pointsFastBreak': 3,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 2,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 3,
#       'steals': 0,
#       'threePointersAttempted': 3,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 1,
#       'twoPointersAttempted': 2,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Josh Okogie',
#      'nameI': 'J. Okogie',
#      'firstName': 'Josh',
#      'familyName': 'Okogie'},
#     {'status': 'ACTIVE',
#      'order': 2,
#      'personId': 1628470,
#      'jerseyNum': '0',
#      'position': 'PF',
#      'starter': '1',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 1,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 10,
#       'fieldGoalsMade': 5,
#       'fieldGoalsPercentage': 0.5,
#       'foulsOffensive': 1,
#       'foulsDrawn': 0,
#       'foulsPersonal': 4,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 71.0,
#       'minutes': 'PT26M34.08S',
#       'minutesCalculated': 'PT27M',
#       'plus': 61.0,
#       'plusMinusPoints': -10.0,
#       'points': 14,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 2,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 2,
#       'steals': 0,
#       'threePointersAttempted': 7,
#       'threePointersMade': 4,
#       'threePointersPercentage': 0.5714285714285711,
#       'turnovers': 1,
#       'twoPointersAttempted': 3,
#       'twoPointersMade': 1,
#       'twoPointersPercentage': 0.333333333333333},
#      'name': 'Torrey Craig',
#      'nameI': 'T. Craig',
#      'firstName': 'Torrey',
#      'familyName': 'Craig'},
#     {'status': 'ACTIVE',
#      'order': 3,
#      'personId': 202687,
#      'jerseyNum': '18',
#      'position': 'C',
#      'starter': '1',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 2,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 4,
#       'fieldGoalsMade': 3,
#       'fieldGoalsPercentage': 0.75,
#       'foulsOffensive': 2,
#       'foulsDrawn': 3,
#       'foulsPersonal': 4,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 2,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 70.0,
#       'minutes': 'PT25M51.08S',
#       'minutesCalculated': 'PT26M',
#       'plus': 57.0,
#       'plusMinusPoints': -13.0,
#       'points': 6,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 6,
#       'pointsSecondChance': 4,
#       'reboundsDefensive': 3,
#       'reboundsOffensive': 5,
#       'reboundsTotal': 8,
#       'steals': 1,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 2,
#       'twoPointersAttempted': 4,
#       'twoPointersMade': 3,
#       'twoPointersPercentage': 0.75},
#      'name': 'Bismack Biyombo',
#      'nameI': 'B. Biyombo',
#      'firstName': 'Bismack',
#      'familyName': 'Biyombo'},
#     {'status': 'ACTIVE',
#      'order': 4,
#      'personId': 1626164,
#      'jerseyNum': '1',
#      'position': 'SG',
#      'starter': '1',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 5,
#       'blocks': 0,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 16,
#       'fieldGoalsMade': 11,
#       'fieldGoalsPercentage': 0.6875,
#       'foulsOffensive': 1,
#       'foulsDrawn': 10,
#       'foulsPersonal': 4,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 12,
#       'freeThrowsMade': 10,
#       'freeThrowsPercentage': 0.833333333333334,
#       'minus': 97.0,
#       'minutes': 'PT40M33.00S',
#       'minutesCalculated': 'PT40M',
#       'plus': 97.0,
#       'plusMinusPoints': 0.0,
#       'points': 33,
#       'pointsFastBreak': 3,
#       'pointsInThePaint': 14,
#       'pointsSecondChance': 2,
#       'reboundsDefensive': 6,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 6,
#       'steals': 0,
#       'threePointersAttempted': 3,
#       'threePointersMade': 1,
#       'threePointersPercentage': 0.333333333333333,
#       'turnovers': 7,
#       'twoPointersAttempted': 13,
#       'twoPointersMade': 10,
#       'twoPointersPercentage': 0.769230769230769},
#      'name': 'Devin Booker',
#      'nameI': 'D. Booker',
#      'firstName': 'Devin',
#      'familyName': 'Booker'},
#     {'status': 'ACTIVE',
#      'order': 5,
#      'personId': 101108,
#      'jerseyNum': '3',
#      'position': 'PG',
#      'starter': '1',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 4,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 17,
#       'fieldGoalsMade': 8,
#       'fieldGoalsPercentage': 0.470588235294118,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 5,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 83.0,
#       'minutes': 'PT30M09.00S',
#       'minutesCalculated': 'PT30M',
#       'plus': 67.0,
#       'plusMinusPoints': -16.0,
#       'points': 18,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 6,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 4,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 4,
#       'steals': 1,
#       'threePointersAttempted': 4,
#       'threePointersMade': 2,
#       'threePointersPercentage': 0.5,
#       'turnovers': 1,
#       'twoPointersAttempted': 13,
#       'twoPointersMade': 6,
#       'twoPointersPercentage': 0.461538461538462},
#      'name': 'Chris Paul',
#      'nameI': 'C. Paul',
#      'firstName': 'Chris',
#      'familyName': 'Paul'},
#     {'status': 'ACTIVE',
#      'order': 6,
#      'personId': 1629111,
#      'jerseyNum': '11',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 6,
#       'fieldGoalsMade': 2,
#       'fieldGoalsPercentage': 0.333333333333333,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 4,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 46.0,
#       'minutes': 'PT20M31.92S',
#       'minutesCalculated': 'PT20M',
#       'plus': 49.0,
#       'plusMinusPoints': 3.0,
#       'points': 4,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 4,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 2,
#       'reboundsOffensive': 3,
#       'reboundsTotal': 5,
#       'steals': 1,
#       'threePointersAttempted': 1,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 1,
#       'twoPointersAttempted': 5,
#       'twoPointersMade': 2,
#       'twoPointersPercentage': 0.4},
#      'name': 'Jock Landale',
#      'nameI': 'J. Landale',
#      'firstName': 'Jock',
#      'familyName': 'Landale'},
#     {'status': 'ACTIVE',
#      'order': 7,
#      'personId': 203933,
#      'jerseyNum': '21',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 6,
#       'fieldGoalsMade': 3,
#       'fieldGoalsPercentage': 0.5,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 45.0,
#       'minutes': 'PT19M39.92S',
#       'minutesCalculated': 'PT20M',
#       'plus': 44.0,
#       'plusMinusPoints': -1.0,
#       'points': 6,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 6,
#       'pointsSecondChance': 2,
#       'reboundsDefensive': 3,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 4,
#       'steals': 0,
#       'threePointersAttempted': 1,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 5,
#       'twoPointersMade': 3,
#       'twoPointersPercentage': 0.6},
#      'name': 'T.J. Warren',
#      'nameI': 'T. Warren',
#      'firstName': 'T.J.',
#      'familyName': 'Warren'},
#     {'status': 'ACTIVE',
#      'order': 8,
#      'personId': 1626166,
#      'jerseyNum': '15',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 2,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 7,
#       'fieldGoalsMade': 3,
#       'fieldGoalsPercentage': 0.428571428571429,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 29.0,
#       'minutes': 'PT13M37.92S',
#       'minutesCalculated': 'PT14M',
#       'plus': 34.0,
#       'plusMinusPoints': 5.0,
#       'points': 7,
#       'pointsFastBreak': 4,
#       'pointsInThePaint': 4,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 2,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 2,
#       'steals': 1,
#       'threePointersAttempted': 2,
#       'threePointersMade': 1,
#       'threePointersPercentage': 0.5,
#       'turnovers': 1,
#       'twoPointersAttempted': 5,
#       'twoPointersMade': 2,
#       'twoPointersPercentage': 0.4},
#      'name': 'Cameron Payne',
#      'nameI': 'C. Payne',
#      'firstName': 'Cameron',
#      'familyName': 'Payne'},
#     {'status': 'ACTIVE',
#      'order': 9,
#      'personId': 1629013,
#      'jerseyNum': '14',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 3,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 13,
#       'fieldGoalsMade': 6,
#       'fieldGoalsPercentage': 0.461538461538462,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 73.0,
#       'minutes': 'PT29M07.00S',
#       'minutesCalculated': 'PT29M',
#       'plus': 66.0,
#       'plusMinusPoints': -7.0,
#       'points': 15,
#       'pointsFastBreak': 3,
#       'pointsInThePaint': 4,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 2,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 3,
#       'steals': 2,
#       'threePointersAttempted': 8,
#       'threePointersMade': 3,
#       'threePointersPercentage': 0.375,
#       'turnovers': 2,
#       'twoPointersAttempted': 5,
#       'twoPointersMade': 3,
#       'twoPointersPercentage': 0.6},
#      'name': 'Landry Shamet',
#      'nameI': 'L. Shamet',
#      'firstName': 'Landry',
#      'familyName': 'Shamet'},
#     {'status': 'ACTIVE',
#      'order': 10,
#      'personId': 203082,
#      'jerseyNum': '8',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 6,
#       'fieldGoalsMade': 1,
#       'fieldGoalsPercentage': 0.166666666666667,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 1,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 40.0,
#       'minutes': 'PT12M26.00S',
#       'minutesCalculated': 'PT12M',
#       'plus': 28.0,
#       'plusMinusPoints': -12.0,
#       'points': 3,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 1,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 2,
#       'steals': 0,
#       'threePointersAttempted': 2,
#       'threePointersMade': 1,
#       'threePointersPercentage': 0.5,
#       'turnovers': 0,
#       'twoPointersAttempted': 4,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Terrence Ross',
#      'nameI': 'T. Ross',
#      'firstName': 'Terrence',
#      'familyName': 'Ross'},
#     {'status': 'ACTIVE',
#      'order': 11,
#      'personId': 1629647,
#      'jerseyNum': '55',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 1,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 6.0,
#       'minutes': 'PT01M37.00S',
#       'minutesCalculated': 'PT02M',
#       'plus': 5.0,
#       'plusMinusPoints': -1.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 1,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 1,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Darius Bazley',
#      'nameI': 'D. Bazley',
#      'firstName': 'Darius',
#      'familyName': 'Bazley'},
#     {'status': 'ACTIVE',
#      'order': 12,
#      'personId': 1627814,
#      'jerseyNum': '10',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Damion Lee',
#      'nameI': 'D. Lee',
#      'firstName': 'Damion',
#      'familyName': 'Lee'},
#     {'status': 'ACTIVE',
#      'order': 13,
#      'personId': 1630688,
#      'jerseyNum': '12',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Ish Wainright',
#      'nameI': 'I. Wainright',
#      'firstName': 'Ish',
#      'familyName': 'Wainright'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Right Hip; Contusion',
#      'order': 14,
#      'personId': 1629028,
#      'jerseyNum': '22',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Deandre Ayton',
#      'nameI': 'D. Ayton',
#      'firstName': 'Deandre',
#      'familyName': 'Ayton'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Left Ankle; Sprain',
#      'order': 15,
#      'personId': 201142,
#      'jerseyNum': '35',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Kevin Durant',
#      'nameI': 'K. Durant',
#      'firstName': 'Kevin',
#      'familyName': 'Durant'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_GLEAGUE_TWOWAY',
#      'order': 16,
#      'personId': 1630240,
#      'jerseyNum': '38',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Saben Lee',
#      'nameI': 'S. Lee',
#      'firstName': 'Saben',
#      'familyName': 'Lee'}],
#    'statistics': {'assists': 23,
#     'assistsTurnoverRatio': 1.35294117647059,
#     'benchPoints': 35,
#     'biggestLead': 6,
#     'biggestLeadScore': '10-4',
#     'biggestScoringRun': 10,
#     'biggestScoringRunScore': '46-56',
#     'blocks': 6,
#     'blocksReceived': 2,
#     'fastBreakPointsAttempted': 8,
#     'fastBreakPointsMade': 4,
#     'fastBreakPointsPercentage': 0.5,
#     'fieldGoalsAttempted': 90,
#     'fieldGoalsEffectiveAdjusted': 0.533333333333333,
#     'fieldGoalsMade': 42,
#     'fieldGoalsPercentage': 0.466666666666667,
#     'foulsOffensive': 4,
#     'foulsDrawn': 20,
#     'foulsPersonal': 31,
#     'foulsTeam': 27,
#     'foulsTechnical': 0,
#     'foulsTeamTechnical': 0,
#     'freeThrowsAttempted': 20,
#     'freeThrowsMade': 15,
#     'freeThrowsPercentage': 0.75,
#     'leadChanges': 6,
#     'minutes': 'PT240M00.00S',
#     'minutesCalculated': 'PT240M',
#     'points': 111,
#     'pointsAgainst': 122,
#     'pointsFastBreak': 13,
#     'pointsFromTurnovers': 18,
#     'pointsInThePaint': 44,
#     'pointsInThePaintAttempted': 45,
#     'pointsInThePaintMade': 22,
#     'pointsInThePaintPercentage': 0.488888888888889,
#     'pointsSecondChance': 8,
#     'reboundsDefensive': 27,
#     'reboundsOffensive': 12,
#     'reboundsPersonal': 39,
#     'reboundsTeam': 7,
#     'reboundsTeamDefensive': 1,
#     'reboundsTeamOffensive': 6,
#     'reboundsTotal': 46,
#     'secondChancePointsAttempted': 10,
#     'secondChancePointsMade': 3,
#     'secondChancePointsPercentage': 0.3,
#     'steals': 7,
#     'threePointersAttempted': 31,
#     'threePointersMade': 12,
#     'threePointersPercentage': 0.387096774193548,
#     'timeLeading': 'PT07M01.03S',
#     'timesTied': 7,
#     'trueShootingAttempts': 98.8,
#     'trueShootingPercentage': 0.561740890688259,
#     'turnovers': 17,
#     'turnoversTeam': 0,
#     'turnoversTotal': 17,
#     'twoPointersAttempted': 59,
#     'twoPointersMade': 30,
#     'twoPointersPercentage': 0.508474576271186}}}}

# %% [markdown]
# ## Close Game

# %%
def close_game

# %%
gameClock = "PT06M51.00S"

#minutes = re.search('PT[0-9][0-9]', gameClock).group().replace("PT","")

times = re.findall('[0-9][0-9]', gameClock)

seconds_in_quarter = 60*int(times[0]) + int(times[1]) + int(times[2])/100

print(seconds_in_quarter)

# %%
games.get_dict()

# %%
from nba_api.stats.static import players

players.find_players_by_first_name('Lebron')
# Out:
# [{'id': 2544,
#   'full_name': 'LeBron James',
#   'first_name': 'LeBron',
#   'last_name': 'James',
#   'is_active': True}]

# %%
from nba_api.stats.endpoints import commonplayerinfo

# %%
cum = commonplayerinfo.CommonPlayerInfo(player_id='2544').get_data_frames()

# %%
cum[1]
# Out:
#    PLAYER_ID   PLAYER_NAME TimeFrame   PTS  AST  REB    PIE
# 0       2544  LeBron James   2022-23  29.5  6.9  8.4  0.174
