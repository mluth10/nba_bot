# %%
import requests
import pandas as pd
import re

# %%
from nba_api.live.nba.endpoints import scoreboard
from nba_api.live.nba.endpoints import boxscore

# %%
# Today's Score Board
games = scoreboard.ScoreBoard()

# dictionary
games.get_dict()
# Out:
# {'meta': {'version': 1,
#   'request': 'https://nba-prod-us-east-1-mediaops-stats.s3.amazonaws.com/NBA/liveData/scoreboard/todaysScoreboard_00.json',
#   'time': '2023-03-06 01:28:34.2834',
#   'code': 200},
#  'scoreboard': {'gameDate': '2023-03-06',
#   'leagueId': '00',
#   'leagueName': 'National Basketball Association',
#   'games': [{'gameId': '0022200971',
#     'gameCode': '20230306/BOSCLE',
#     'gameStatus': 1,
#     'gameStatusText': '7:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-07T00:00:00Z',
#     'gameEt': '2023-03-06T19:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'homeTeam': {'teamId': 1610612739,
#      'teamName': 'Cavaliers',
#      'teamCity': 'Cleveland',
#      'teamTricode': 'CLE',
#      'wins': 40,
#      'losses': 26,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612738,
#      'teamName': 'Celtics',
#      'teamCity': 'Boston',
#      'teamTricode': 'BOS',
#      'wins': 45,
#      'losses': 20,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'CLE',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'BOS',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022200972',
#     'gameCode': '20230306/PHIIND',
#     'gameStatus': 1,
#     'gameStatusText': '7:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-07T00:00:00Z',
#     'gameEt': '2023-03-06T19:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'homeTeam': {'teamId': 1610612754,
#      'teamName': 'Pacers',
#      'teamCity': 'Indiana',
#      'teamTricode': 'IND',
#      'wins': 29,
#      'losses': 36,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612755,
#      'teamName': '76ers',
#      'teamCity': 'Philadelphia',
#      'teamTricode': 'PHI',
#      'wins': 41,
#      'losses': 22,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'IND',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'PHI',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022200977',
#     'gameCode': '20230306/PORDET',
#     'gameStatus': 1,
#     'gameStatusText': '7:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-07T00:00:00Z',
#     'gameEt': '2023-03-06T19:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'homeTeam': {'teamId': 1610612765,
#      'teamName': 'Pistons',
#      'teamCity': 'Detroit',
#      'teamTricode': 'DET',
#      'wins': 15,
#      'losses': 49,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612757,
#      'teamName': 'Trail Blazers',
#      'teamCity': 'Portland',
#      'teamTricode': 'POR',
#      'wins': 30,
#      'losses': 34,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'DET',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'POR',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022200974',
#     'gameCode': '20230306/ATLMIA',
#     'gameStatus': 1,
#     'gameStatusText': '7:30 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-07T00:30:00Z',
#     'gameEt': '2023-03-06T19:30:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'homeTeam': {'teamId': 1610612748,
#      'teamName': 'Heat',
#      'teamCity': 'Miami',
#      'teamTricode': 'MIA',
#      'wins': 34,
#      'losses': 31,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612737,
#      'teamName': 'Hawks',
#      'teamCity': 'Atlanta',
#      'teamTricode': 'ATL',
#      'wins': 32,
#      'losses': 32,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'MIA',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'ATL',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022200975',
#     'gameCode': '20230306/TORDEN',
#     'gameStatus': 1,
#     'gameStatusText': '9:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-07T02:00:00Z',
#     'gameEt': '2023-03-06T21:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'homeTeam': {'teamId': 1610612743,
#      'teamName': 'Nuggets',
#      'teamCity': 'Denver',
#      'teamTricode': 'DEN',
#      'wins': 45,
#      'losses': 19,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612761,
#      'teamName': 'Raptors',
#      'teamCity': 'Toronto',
#      'teamTricode': 'TOR',
#      'wins': 32,
#      'losses': 33,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'DEN',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'TOR',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}},
#    {'gameId': '0022200976',
#     'gameCode': '20230306/NOPSAC',
#     'gameStatus': 1,
#     'gameStatusText': '10:00 pm ET',
#     'period': 0,
#     'gameClock': '',
#     'gameTimeUTC': '2023-03-07T03:00:00Z',
#     'gameEt': '2023-03-06T22:00:00Z',
#     'regulationPeriods': 4,
#     'ifNecessary': False,
#     'seriesGameNumber': '',
#     'seriesText': '',
#     'homeTeam': {'teamId': 1610612758,
#      'teamName': 'Kings',
#      'teamCity': 'Sacramento',
#      'teamTricode': 'SAC',
#      'wins': 37,
#      'losses': 26,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'awayTeam': {'teamId': 1610612740,
#      'teamName': 'Pelicans',
#      'teamCity': 'New Orleans',
#      'teamTricode': 'NOP',
#      'wins': 31,
#      'losses': 33,
#      'score': 0,
#      'seed': None,
#      'inBonus': None,
#      'timeoutsRemaining': 0,
#      'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 2, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 3, 'periodType': 'REGULAR', 'score': 0},
#       {'period': 4, 'periodType': 'REGULAR', 'score': 0}]},
#     'gameLeaders': {'homeLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'SAC',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0},
#      'awayLeaders': {'personId': 0,
#       'name': '',
#       'jerseyNum': '',
#       'position': '',
#       'teamTricode': 'NOP',
#       'playerSlug': None,
#       'points': 0,
#       'rebounds': 0,
#       'assists': 0}},
#     'pbOdds': {'team': None, 'odds': 0.0, 'suspended': 0}}]}}

# %% [markdown]
# ### Get list of active games

# %%
games = scoreboard.ScoreBoard()

# dictionary
board = games.get_dict()

all_games = board['scoreboard']['games']
active_games = []

for game in all_games:
    if game['gameStatus'] == 2:
        active_games.append(game)

active_games
# Out:
# []

# %%
boxscore.BoxScore('0022200547').get_dict()
# Out:
# {'meta': {'version': 1,
#   'code': 200,
#   'request': 'http://nba.cloud/games/0022200547/boxscore?Format=json',
#   'time': '2023-01-02 01:37:37.002587'},
#  'game': {'gameId': '0022200547',
#   'gameTimeLocal': '2023-01-01T19:00:00-06:00',
#   'gameTimeUTC': '2023-01-02T01:00:00Z',
#   'gameTimeHome': '2023-01-01T19:00:00-06:00',
#   'gameTimeAway': '2023-01-01T17:00:00-08:00',
#   'gameEt': '2023-01-01T20:00:00-05:00',
#   'duration': 131,
#   'gameCode': '20230101/SACMEM',
#   'gameStatusText': 'Final',
#   'gameStatus': 3,
#   'regulationPeriods': 4,
#   'period': 4,
#   'gameClock': 'PT00M00.00S',
#   'attendance': 17794,
#   'sellout': '1',
#   'arena': {'arenaId': 242,
#    'arenaName': 'FedExForum',
#    'arenaCity': 'Memphis',
#    'arenaState': 'TN',
#    'arenaCountry': 'US',
#    'arenaTimezone': 'America/Chicago'},
#   'officials': [{'personId': 204058,
#     'name': 'Gediminas Petraitis',
#     'nameI': 'G. Petraitis',
#     'firstName': 'Gediminas',
#     'familyName': 'Petraitis',
#     'jerseyNum': '50',
#     'assignment': 'OFFICIAL1'},
#    {'personId': 1626301,
#     'name': 'Jason Goldenberg',
#     'nameI': 'J. Goldenberg',
#     'firstName': 'Jason',
#     'familyName': 'Goldenberg',
#     'jerseyNum': '35',
#     'assignment': 'OFFICIAL3'},
#    {'personId': 1627962,
#     'name': 'Jacyn Goble',
#     'nameI': 'J. Goble',
#     'firstName': 'Jacyn',
#     'familyName': 'Goble',
#     'jerseyNum': '68',
#     'assignment': 'OFFICIAL2'}],
#   'homeTeam': {'teamId': 1610612763,
#    'teamName': 'Grizzlies',
#    'teamCity': 'Memphis',
#    'teamTricode': 'MEM',
#    'score': 118,
#    'inBonus': '0',
#    'timeoutsRemaining': 2,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 27},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 32},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 32},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 27}],
#    'players': [{'status': 'ACTIVE',
#      'order': 1,
#      'personId': 1628415,
#      'jerseyNum': '24',
#      'position': 'SF',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 1,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 19,
#       'fieldGoalsMade': 7,
#       'fieldGoalsPercentage': 0.368421052631579,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 83.0,
#       'minutes': 'PT36M05.93S',
#       'minutesCalculated': 'PT36M',
#       'plus': 86.0,
#       'plusMinusPoints': 3.0,
#       'points': 15,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 8,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 1,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 2,
#       'steals': 1,
#       'threePointersAttempted': 6,
#       'threePointersMade': 1,
#       'threePointersPercentage': 0.166666666666667,
#       'turnovers': 3,
#       'twoPointersAttempted': 13,
#       'twoPointersMade': 6,
#       'twoPointersPercentage': 0.461538461538462},
#      'name': 'Dillon Brooks',
#      'nameI': 'D. Brooks',
#      'firstName': 'Dillon',
#      'familyName': 'Brooks'},
#     {'status': 'ACTIVE',
#      'order': 2,
#      'personId': 1628991,
#      'jerseyNum': '13',
#      'position': 'PF',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 3,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 11,
#       'fieldGoalsMade': 5,
#       'fieldGoalsPercentage': 0.45454545454545503,
#       'foulsOffensive': 0,
#       'foulsDrawn': 2,
#       'foulsPersonal': 3,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 3,
#       'freeThrowsMade': 2,
#       'freeThrowsPercentage': 0.666666666666666,
#       'minus': 64.0,
#       'minutes': 'PT28M57.93S',
#       'minutesCalculated': 'PT29M',
#       'plus': 71.0,
#       'plusMinusPoints': 7.0,
#       'points': 14,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 6,
#       'pointsSecondChance': 2,
#       'reboundsDefensive': 5,
#       'reboundsOffensive': 2,
#       'reboundsTotal': 7,
#       'steals': 0,
#       'threePointersAttempted': 4,
#       'threePointersMade': 2,
#       'threePointersPercentage': 0.5,
#       'turnovers': 0,
#       'twoPointersAttempted': 7,
#       'twoPointersMade': 3,
#       'twoPointersPercentage': 0.428571428571429},
#      'name': 'Jaren Jackson Jr.',
#      'nameI': 'J. Jackson Jr.',
#      'firstName': 'Jaren',
#      'familyName': 'Jackson Jr.'},
#     {'status': 'ACTIVE',
#      'order': 3,
#      'personId': 203500,
#      'jerseyNum': '4',
#      'position': 'C',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 3,
#       'blocks': 2,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 12,
#       'fieldGoalsMade': 5,
#       'fieldGoalsPercentage': 0.416666666666667,
#       'foulsOffensive': 1,
#       'foulsDrawn': 3,
#       'foulsPersonal': 4,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 2,
#       'freeThrowsMade': 1,
#       'freeThrowsPercentage': 0.5,
#       'minus': 77.0,
#       'minutes': 'PT34M29.88S',
#       'minutesCalculated': 'PT34M',
#       'plus': 81.0,
#       'plusMinusPoints': 4.0,
#       'points': 11,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 10,
#       'pointsSecondChance': 5,
#       'reboundsDefensive': 10,
#       'reboundsOffensive': 13,
#       'reboundsTotal': 23,
#       'steals': 1,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 4,
#       'twoPointersAttempted': 12,
#       'twoPointersMade': 5,
#       'twoPointersPercentage': 0.416666666666667},
#      'name': 'Steven Adams',
#      'nameI': 'S. Adams',
#      'firstName': 'Steven',
#      'familyName': 'Adams'},
#     {'status': 'ACTIVE',
#      'order': 4,
#      'personId': 1629723,
#      'jerseyNum': '46',
#      'position': 'SG',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 11,
#       'fieldGoalsMade': 5,
#       'fieldGoalsPercentage': 0.45454545454545503,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 1,
#       'freeThrowsMade': 1,
#       'freeThrowsPercentage': 1.0,
#       'minus': 69.0,
#       'minutes': 'PT27M38.00S',
#       'minutesCalculated': 'PT28M',
#       'plus': 69.0,
#       'plusMinusPoints': 0.0,
#       'points': 12,
#       'pointsFastBreak': 7,
#       'pointsInThePaint': 8,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 4,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 5,
#       'steals': 3,
#       'threePointersAttempted': 6,
#       'threePointersMade': 1,
#       'threePointersPercentage': 0.166666666666667,
#       'turnovers': 1,
#       'twoPointersAttempted': 5,
#       'twoPointersMade': 4,
#       'twoPointersPercentage': 0.8},
#      'name': 'John Konchar',
#      'nameI': 'J. Konchar',
#      'firstName': 'John',
#      'familyName': 'Konchar'},
#     {'status': 'ACTIVE',
#      'order': 5,
#      'personId': 1629630,
#      'jerseyNum': '12',
#      'position': 'PG',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 5,
#       'blocks': 1,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 23,
#       'fieldGoalsMade': 13,
#       'fieldGoalsPercentage': 0.565217391304348,
#       'foulsOffensive': 1,
#       'foulsDrawn': 8,
#       'foulsPersonal': 4,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 10,
#       'freeThrowsMade': 8,
#       'freeThrowsPercentage': 0.8,
#       'minus': 71.0,
#       'minutes': 'PT32M47.93S',
#       'minutesCalculated': 'PT33M',
#       'plus': 79.0,
#       'plusMinusPoints': 8.0,
#       'points': 35,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 22,
#       'pointsSecondChance': 4,
#       'reboundsDefensive': 7,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 8,
#       'steals': 1,
#       'threePointersAttempted': 5,
#       'threePointersMade': 1,
#       'threePointersPercentage': 0.2,
#       'turnovers': 3,
#       'twoPointersAttempted': 18,
#       'twoPointersMade': 12,
#       'twoPointersPercentage': 0.666666666666666},
#      'name': 'Ja Morant',
#      'nameI': 'J. Morant',
#      'firstName': 'Ja',
#      'familyName': 'Morant'},
#     {'status': 'ACTIVE',
#      'order': 6,
#      'personId': 1631223,
#      'jerseyNum': '27',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 6,
#       'fieldGoalsMade': 2,
#       'fieldGoalsPercentage': 0.333333333333333,
#       'foulsOffensive': 0,
#       'foulsDrawn': 2,
#       'foulsPersonal': 1,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 4,
#       'freeThrowsMade': 1,
#       'freeThrowsPercentage': 0.25,
#       'minus': 31.0,
#       'minutes': 'PT15M06.00S',
#       'minutesCalculated': 'PT15M',
#       'plus': 41.0,
#       'plusMinusPoints': 10.0,
#       'points': 5,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 4,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 2,
#       'reboundsOffensive': 2,
#       'reboundsTotal': 4,
#       'steals': 1,
#       'threePointersAttempted': 3,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 3,
#       'twoPointersMade': 2,
#       'twoPointersPercentage': 0.666666666666666},
#      'name': 'David Roddy',
#      'nameI': 'D. Roddy',
#      'firstName': 'David',
#      'familyName': 'Roddy'},
#     {'status': 'ACTIVE',
#      'order': 7,
#      'personId': 1626145,
#      'jerseyNum': '21',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 8,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 10,
#       'fieldGoalsMade': 5,
#       'fieldGoalsPercentage': 0.5,
#       'foulsOffensive': 0,
#       'foulsDrawn': 2,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 4,
#       'freeThrowsMade': 3,
#       'freeThrowsPercentage': 0.75,
#       'minus': 66.0,
#       'minutes': 'PT32M18.98S',
#       'minutesCalculated': 'PT32M',
#       'plus': 80.0,
#       'plusMinusPoints': 14.0,
#       'points': 18,
#       'pointsFastBreak': 9,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 4,
#       'reboundsDefensive': 6,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 6,
#       'steals': 1,
#       'threePointersAttempted': 7,
#       'threePointersMade': 5,
#       'threePointersPercentage': 0.714285714285714,
#       'turnovers': 0,
#       'twoPointersAttempted': 3,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Tyus Jones',
#      'nameI': 'T. Jones',
#      'firstName': 'Tyus',
#      'familyName': 'Jones'},
#     {'status': 'ACTIVE',
#      'order': 8,
#      'personId': 1630214,
#      'jerseyNum': '2',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 4,
#       'fieldGoalsMade': 2,
#       'fieldGoalsPercentage': 0.5,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 31.0,
#       'minutes': 'PT12M35.07S',
#       'minutesCalculated': 'PT13M',
#       'plus': 37.0,
#       'plusMinusPoints': 6.0,
#       'points': 4,
#       'pointsFastBreak': 2,
#       'pointsInThePaint': 4,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 1,
#       'steals': 2,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 4,
#       'twoPointersMade': 2,
#       'twoPointersPercentage': 0.5},
#      'name': 'Xavier Tillman',
#      'nameI': 'X. Tillman',
#      'firstName': 'Xavier',
#      'familyName': 'Tillman'},
#     {'status': 'ACTIVE',
#      'order': 9,
#      'personId': 1631222,
#      'jerseyNum': '3',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 9.0,
#       'minutes': 'PT04M01.07S',
#       'minutesCalculated': 'PT04M',
#       'plus': 7.0,
#       'plusMinusPoints': -2.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Jake LaRavia',
#      'nameI': 'J. LaRavia',
#      'firstName': 'Jake',
#      'familyName': 'LaRavia'},
#     {'status': 'ACTIVE',
#      'order': 10,
#      'personId': 1631113,
#      'jerseyNum': '1',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 1,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 3,
#       'fieldGoalsMade': 2,
#       'fieldGoalsPercentage': 0.666666666666666,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 35.0,
#       'minutes': 'PT14M03.07S',
#       'minutesCalculated': 'PT14M',
#       'plus': 39.0,
#       'plusMinusPoints': 4.0,
#       'points': 4,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 1,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 1,
#       'steals': 1,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 3,
#       'twoPointersMade': 2,
#       'twoPointersPercentage': 0.666666666666666},
#      'name': 'Kennedy Chandler',
#      'nameI': 'K. Chandler',
#      'firstName': 'Kennedy',
#      'familyName': 'Chandler'},
#     {'status': 'ACTIVE',
#      'order': 11,
#      'personId': 1631246,
#      'jerseyNum': '5',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 2.0,
#       'minutes': 'PT00M58.07S',
#       'minutesCalculated': 'PT01M',
#       'plus': 0.0,
#       'plusMinusPoints': -2.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Vince Williams Jr.',
#      'nameI': 'V. Williams Jr.',
#      'firstName': 'Vince',
#      'familyName': 'Williams Jr.'},
#     {'status': 'ACTIVE',
#      'order': 12,
#      'personId': 1631254,
#      'jerseyNum': '6',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 1,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 2.0,
#       'minutes': 'PT00M58.07S',
#       'minutesCalculated': 'PT01M',
#       'plus': 0.0,
#       'plusMinusPoints': -2.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 1,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Kenneth Lofton Jr.',
#      'nameI': 'K. Lofton Jr.',
#      'firstName': 'Kenneth',
#      'familyName': 'Lofton Jr.'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Left Ankle; Soreness',
#      'order': 13,
#      'personId': 1630583,
#      'jerseyNum': '7',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Santi Aldama',
#      'nameI': 'S. Aldama',
#      'firstName': 'Santi',
#      'familyName': 'Aldama'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Right Big Toe; RTN from Injury Management',
#      'order': 14,
#      'personId': 1630217,
#      'jerseyNum': '22',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Desmond Bane',
#      'nameI': 'D. Bane',
#      'firstName': 'Desmond',
#      'familyName': 'Bane'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Left Hip; Soreness',
#      'order': 15,
#      'personId': 1629634,
#      'jerseyNum': '15',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Brandon Clarke',
#      'nameI': 'B. Clarke',
#      'firstName': 'Brandon',
#      'familyName': 'Clarke'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Left Knee; Surgery Recovery',
#      'order': 16,
#      'personId': 201980,
#      'jerseyNum': '14',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Danny Green',
#      'nameI': 'D. Green',
#      'firstName': 'Danny',
#      'familyName': 'Green'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_INJURY',
#      'notPlayingDescription': 'Right Knee; Soreness',
#      'order': 17,
#      'personId': 1630533,
#      'jerseyNum': '8',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Ziaire Williams',
#      'nameI': 'Z. Williams',
#      'firstName': 'Ziaire',
#      'familyName': 'Williams'}],
#    'statistics': {'assists': 25,
#     'assistsTurnoverRatio': 2.08333333333333,
#     'benchPoints': 31,
#     'biggestLead': 14,
#     'biggestLeadScore': '97-111',
#     'biggestScoringRun': 12,
#     'biggestScoringRunScore': '79-86',
#     'blocks': 8,
#     'blocksReceived': 4,
#     'fastBreakPointsAttempted': 10,
#     'fastBreakPointsMade': 7,
#     'fastBreakPointsPercentage': 0.7,
#     'fieldGoalsAttempted': 100,
#     'fieldGoalsEffectiveAdjusted': 0.51,
#     'fieldGoalsMade': 46,
#     'fieldGoalsPercentage': 0.46,
#     'foulsOffensive': 2,
#     'foulsDrawn': 18,
#     'foulsPersonal': 18,
#     'foulsTeam': 16,
#     'foulsTechnical': 0,
#     'foulsTeamTechnical': 1,
#     'freeThrowsAttempted': 24,
#     'freeThrowsMade': 16,
#     'freeThrowsPercentage': 0.666666666666666,
#     'leadChanges': 11,
#     'minutes': 'PT240M00.00S',
#     'minutesCalculated': 'PT240M',
#     'points': 118,
#     'pointsAgainst': 108,
#     'pointsFastBreak': 18,
#     'pointsFromTurnovers': 24,
#     'pointsInThePaint': 64,
#     'pointsInThePaintAttempted': 62,
#     'pointsInThePaintMade': 32,
#     'pointsInThePaintPercentage': 0.516129032258064,
#     'pointsSecondChance': 15,
#     'reboundsDefensive': 36,
#     'reboundsOffensive': 21,
#     'reboundsPersonal': 57,
#     'reboundsTeam': 9,
#     'reboundsTeamDefensive': 2,
#     'reboundsTeamOffensive': 7,
#     'reboundsTotal': 66,
#     'secondChancePointsAttempted': 18,
#     'secondChancePointsMade': 6,
#     'secondChancePointsPercentage': 0.333333333333333,
#     'steals': 11,
#     'threePointersAttempted': 32,
#     'threePointersMade': 10,
#     'threePointersPercentage': 0.3125,
#     'timeLeading': 'PT30M43.00S',
#     'timesTied': 8,
#     'trueShootingAttempts': 110.56,
#     'trueShootingPercentage': 0.533646888567294,
#     'turnovers': 11,
#     'turnoversTeam': 1,
#     'turnoversTotal': 12,
#     'twoPointersAttempted': 68,
#     'twoPointersMade': 36,
#     'twoPointersPercentage': 0.529411764705882}},
#   'awayTeam': {'teamId': 1610612758,
#    'teamName': 'Kings',
#    'teamCity': 'Sacramento',
#    'teamTricode': 'SAC',
#    'score': 108,
#    'inBonus': '0',
#    'timeoutsRemaining': 2,
#    'periods': [{'period': 1, 'periodType': 'REGULAR', 'score': 26},
#     {'period': 2, 'periodType': 'REGULAR', 'score': 32},
#     {'period': 3, 'periodType': 'REGULAR', 'score': 29},
#     {'period': 4, 'periodType': 'REGULAR', 'score': 21}],
#    'players': [{'status': 'ACTIVE',
#      'order': 1,
#      'personId': 203084,
#      'jerseyNum': '40',
#      'position': 'SF',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 12,
#       'fieldGoalsMade': 4,
#       'fieldGoalsPercentage': 0.333333333333333,
#       'foulsOffensive': 0,
#       'foulsDrawn': 3,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 4,
#       'freeThrowsMade': 4,
#       'freeThrowsPercentage': 1.0,
#       'minus': 73.0,
#       'minutes': 'PT28M32.00S',
#       'minutesCalculated': 'PT29M',
#       'plus': 71.0,
#       'plusMinusPoints': -2.0,
#       'points': 16,
#       'pointsFastBreak': 3,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 2,
#       'reboundsDefensive': 5,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 5,
#       'steals': 1,
#       'threePointersAttempted': 9,
#       'threePointersMade': 4,
#       'threePointersPercentage': 0.444444444444444,
#       'turnovers': 2,
#       'twoPointersAttempted': 3,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Harrison Barnes',
#      'nameI': 'H. Barnes',
#      'firstName': 'Harrison',
#      'familyName': 'Barnes'},
#     {'status': 'ACTIVE',
#      'order': 2,
#      'personId': 1631099,
#      'jerseyNum': '13',
#      'position': 'PF',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 2,
#       'fieldGoalsAttempted': 12,
#       'fieldGoalsMade': 4,
#       'fieldGoalsPercentage': 0.333333333333333,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 72.0,
#       'minutes': 'PT27M44.00S',
#       'minutesCalculated': 'PT28M',
#       'plus': 68.0,
#       'plusMinusPoints': -4.0,
#       'points': 10,
#       'pointsFastBreak': 3,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 3,
#       'reboundsTotal': 3,
#       'steals': 2,
#       'threePointersAttempted': 6,
#       'threePointersMade': 2,
#       'threePointersPercentage': 0.333333333333333,
#       'turnovers': 0,
#       'twoPointersAttempted': 6,
#       'twoPointersMade': 2,
#       'twoPointersPercentage': 0.333333333333333},
#      'name': 'Keegan Murray',
#      'nameI': 'K. Murray',
#      'firstName': 'Keegan',
#      'familyName': 'Murray'},
#     {'status': 'ACTIVE',
#      'order': 3,
#      'personId': 1627734,
#      'jerseyNum': '10',
#      'position': 'C',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 4,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 14,
#       'fieldGoalsMade': 8,
#       'fieldGoalsPercentage': 0.5714285714285711,
#       'foulsOffensive': 0,
#       'foulsDrawn': 4,
#       'foulsPersonal': 4,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 2,
#       'freeThrowsMade': 2,
#       'freeThrowsPercentage': 1.0,
#       'minus': 76.0,
#       'minutes': 'PT32M57.00S',
#       'minutesCalculated': 'PT33M',
#       'plus': 75.0,
#       'plusMinusPoints': -1.0,
#       'points': 18,
#       'pointsFastBreak': 2,
#       'pointsInThePaint': 16,
#       'pointsSecondChance': 7,
#       'reboundsDefensive': 8,
#       'reboundsOffensive': 6,
#       'reboundsTotal': 14,
#       'steals': 1,
#       'threePointersAttempted': 2,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 12,
#       'twoPointersMade': 8,
#       'twoPointersPercentage': 0.666666666666666},
#      'name': 'Domantas Sabonis',
#      'nameI': 'D. Sabonis',
#      'firstName': 'Domantas',
#      'familyName': 'Sabonis'},
#     {'status': 'ACTIVE',
#      'order': 4,
#      'personId': 1628989,
#      'jerseyNum': '9',
#      'position': 'SG',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 5,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 10,
#       'fieldGoalsMade': 4,
#       'fieldGoalsPercentage': 0.4,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 3,
#       'freeThrowsMade': 3,
#       'freeThrowsPercentage': 1.0,
#       'minus': 78.0,
#       'minutes': 'PT32M11.08S',
#       'minutesCalculated': 'PT32M',
#       'plus': 71.0,
#       'plusMinusPoints': -7.0,
#       'points': 14,
#       'pointsFastBreak': 3,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 6,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 6,
#       'steals': 2,
#       'threePointersAttempted': 7,
#       'threePointersMade': 3,
#       'threePointersPercentage': 0.428571428571429,
#       'turnovers': 1,
#       'twoPointersAttempted': 3,
#       'twoPointersMade': 1,
#       'twoPointersPercentage': 0.333333333333333},
#      'name': 'Kevin Huerter',
#      'nameI': 'K. Huerter',
#      'firstName': 'Kevin',
#      'familyName': 'Huerter'},
#     {'status': 'ACTIVE',
#      'order': 5,
#      'personId': 1628368,
#      'jerseyNum': '5',
#      'position': 'PG',
#      'starter': '1',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 6,
#       'blocks': 0,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 18,
#       'fieldGoalsMade': 7,
#       'fieldGoalsPercentage': 0.388888888888889,
#       'foulsOffensive': 0,
#       'foulsDrawn': 4,
#       'foulsPersonal': 1,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 3,
#       'freeThrowsMade': 3,
#       'freeThrowsPercentage': 1.0,
#       'minus': 88.0,
#       'minutes': 'PT35M32.00S',
#       'minutesCalculated': 'PT36M',
#       'plus': 86.0,
#       'plusMinusPoints': -2.0,
#       'points': 19,
#       'pointsFastBreak': 2,
#       'pointsInThePaint': 8,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 3,
#       'reboundsOffensive': 1,
#       'reboundsTotal': 4,
#       'steals': 1,
#       'threePointersAttempted': 4,
#       'threePointersMade': 2,
#       'threePointersPercentage': 0.5,
#       'turnovers': 5,
#       'twoPointersAttempted': 14,
#       'twoPointersMade': 5,
#       'twoPointersPercentage': 0.357142857142857},
#      'name': "De'Aaron Fox",
#      'nameI': 'D. Fox',
#      'firstName': "De'Aaron",
#      'familyName': 'Fox'},
#     {'status': 'ACTIVE',
#      'order': 6,
#      'personId': 1626158,
#      'jerseyNum': '22',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 2,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 1,
#       'fieldGoalsMade': 1,
#       'fieldGoalsPercentage': 1.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 1,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 42.0,
#       'minutes': 'PT13M37.00S',
#       'minutesCalculated': 'PT14M',
#       'plus': 31.0,
#       'plusMinusPoints': -11.0,
#       'points': 2,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 3,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 3,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 1,
#       'twoPointersAttempted': 1,
#       'twoPointersMade': 1,
#       'twoPointersPercentage': 1.0},
#      'name': 'Richaun Holmes',
#      'nameI': 'R. Holmes',
#      'firstName': 'Richaun',
#      'familyName': 'Holmes'},
#     {'status': 'ACTIVE',
#      'order': 7,
#      'personId': 1628370,
#      'jerseyNum': '0',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 3,
#       'blocks': 0,
#       'blocksReceived': 3,
#       'fieldGoalsAttempted': 17,
#       'fieldGoalsMade': 7,
#       'fieldGoalsPercentage': 0.411764705882353,
#       'foulsOffensive': 0,
#       'foulsDrawn': 2,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 1,
#       'freeThrowsMade': 1,
#       'freeThrowsPercentage': 1.0,
#       'minus': 65.0,
#       'minutes': 'PT26M19.00S',
#       'minutesCalculated': 'PT26M',
#       'plus': 56.0,
#       'plusMinusPoints': -9.0,
#       'points': 18,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 8,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 3,
#       'reboundsOffensive': 2,
#       'reboundsTotal': 5,
#       'steals': 0,
#       'threePointersAttempted': 8,
#       'threePointersMade': 3,
#       'threePointersPercentage': 0.375,
#       'turnovers': 4,
#       'twoPointersAttempted': 9,
#       'twoPointersMade': 4,
#       'twoPointersPercentage': 0.444444444444444},
#      'name': 'Malik Monk',
#      'nameI': 'M. Monk',
#      'firstName': 'Malik',
#      'familyName': 'Monk'},
#     {'status': 'ACTIVE',
#      'order': 8,
#      'personId': 1630558,
#      'jerseyNum': '15',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 1,
#       'fieldGoalsAttempted': 4,
#       'fieldGoalsMade': 1,
#       'fieldGoalsPercentage': 0.25,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 3,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 46.0,
#       'minutes': 'PT15M14.00S',
#       'minutesCalculated': 'PT15M',
#       'plus': 33.0,
#       'plusMinusPoints': -13.0,
#       'points': 2,
#       'pointsFastBreak': 2,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 2,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 2,
#       'twoPointersMade': 1,
#       'twoPointersPercentage': 0.5},
#      'name': 'Davion Mitchell',
#      'nameI': 'D. Mitchell',
#      'firstName': 'Davion',
#      'familyName': 'Mitchell'},
#     {'status': 'ACTIVE',
#      'order': 9,
#      'personId': 1626168,
#      'jerseyNum': '41',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '1',
#      'statistics': {'assists': 2,
#       'blocks': 2,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 7,
#       'fieldGoalsMade': 2,
#       'fieldGoalsPercentage': 0.28571428571428603,
#       'foulsOffensive': 0,
#       'foulsDrawn': 2,
#       'foulsPersonal': 2,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 2,
#       'freeThrowsMade': 2,
#       'freeThrowsPercentage': 1.0,
#       'minus': 45.0,
#       'minutes': 'PT18M02.00S',
#       'minutesCalculated': 'PT18M',
#       'plus': 35.0,
#       'plusMinusPoints': -10.0,
#       'points': 7,
#       'pointsFastBreak': 2,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 2,
#       'reboundsDefensive': 3,
#       'reboundsOffensive': 2,
#       'reboundsTotal': 5,
#       'steals': 0,
#       'threePointersAttempted': 5,
#       'threePointersMade': 1,
#       'threePointersPercentage': 0.2,
#       'turnovers': 1,
#       'twoPointersAttempted': 2,
#       'twoPointersMade': 1,
#       'twoPointersPercentage': 0.5},
#      'name': 'Trey Lyles',
#      'nameI': 'T. Lyles',
#      'firstName': 'Trey',
#      'familyName': 'Lyles'},
#     {'status': 'ACTIVE',
#      'order': 10,
#      'personId': 1629644,
#      'jerseyNum': '30',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 1,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 5.0,
#       'minutes': 'PT04M07.92S',
#       'minutesCalculated': 'PT04M',
#       'plus': 6.0,
#       'plusMinusPoints': 1.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 1,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 1,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'KZ Okpala',
#      'nameI': 'K. Okpala',
#      'firstName': 'KZ',
#      'familyName': 'Okpala'},
#     {'status': 'ACTIVE',
#      'order': 11,
#      'personId': 1629056,
#      'jerseyNum': '3',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT01M26.00S',
#       'minutesCalculated': 'PT02M',
#       'plus': 2.0,
#       'plusMinusPoints': 2.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Terence Davis',
#      'nameI': 'T. Davis',
#      'firstName': 'Terence',
#      'familyName': 'Davis'},
#     {'status': 'ACTIVE',
#      'order': 12,
#      'personId': 1629002,
#      'jerseyNum': '7',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 1,
#       'fieldGoalsMade': 1,
#       'fieldGoalsPercentage': 1.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT01M26.00S',
#       'minutesCalculated': 'PT01M',
#       'plus': 2.0,
#       'plusMinusPoints': 2.0,
#       'points': 2,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 2,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 1,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 1,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 1,
#       'twoPointersMade': 1,
#       'twoPointersPercentage': 1.0},
#      'name': 'Chimezie Metu',
#      'nameI': 'C. Metu',
#      'firstName': 'Chimezie',
#      'familyName': 'Metu'},
#     {'status': 'ACTIVE',
#      'order': 13,
#      'personId': 203521,
#      'jerseyNum': '8',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT01M26.00S',
#       'minutesCalculated': 'PT01M',
#       'plus': 2.0,
#       'plusMinusPoints': 2.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Matthew Dellavedova',
#      'nameI': 'M. Dellavedova',
#      'firstName': 'Matthew',
#      'familyName': 'Dellavedova'},
#     {'status': 'ACTIVE',
#      'order': 14,
#      'personId': 203458,
#      'jerseyNum': '25',
#      'starter': '0',
#      'oncourt': '1',
#      'played': '1',
#      'statistics': {'assists': 1,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 1,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT01M26.00S',
#       'minutesCalculated': 'PT01M',
#       'plus': 2.0,
#       'plusMinusPoints': 2.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 1,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Alex Len',
#      'nameI': 'A. Len',
#      'firstName': 'Alex',
#      'familyName': 'Len'},
#     {'status': 'ACTIVE',
#      'order': 15,
#      'personId': 1629674,
#      'jerseyNum': '88',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Neemias Queta',
#      'nameI': 'N. Queta',
#      'firstName': 'Neemias',
#      'familyName': 'Queta'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_GLEAGUE_TWOWAY',
#      'order': 16,
#      'personId': 1631165,
#      'jerseyNum': '23',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Keon Ellis',
#      'nameI': 'K. Ellis',
#      'firstName': 'Keon',
#      'familyName': 'Ellis'},
#     {'status': 'INACTIVE',
#      'notPlayingReason': 'INACTIVE_GLEAGUE_ON_ASSIGNMENT',
#      'order': 17,
#      'personId': 1631320,
#      'jerseyNum': '19',
#      'starter': '0',
#      'oncourt': '0',
#      'played': '0',
#      'statistics': {'assists': 0,
#       'blocks': 0,
#       'blocksReceived': 0,
#       'fieldGoalsAttempted': 0,
#       'fieldGoalsMade': 0,
#       'fieldGoalsPercentage': 0.0,
#       'foulsOffensive': 0,
#       'foulsDrawn': 0,
#       'foulsPersonal': 0,
#       'foulsTechnical': 0,
#       'freeThrowsAttempted': 0,
#       'freeThrowsMade': 0,
#       'freeThrowsPercentage': 0.0,
#       'minus': 0.0,
#       'minutes': 'PT00M00.00S',
#       'minutesCalculated': 'PT00M',
#       'plus': 0.0,
#       'plusMinusPoints': 0.0,
#       'points': 0,
#       'pointsFastBreak': 0,
#       'pointsInThePaint': 0,
#       'pointsSecondChance': 0,
#       'reboundsDefensive': 0,
#       'reboundsOffensive': 0,
#       'reboundsTotal': 0,
#       'steals': 0,
#       'threePointersAttempted': 0,
#       'threePointersMade': 0,
#       'threePointersPercentage': 0.0,
#       'turnovers': 0,
#       'twoPointersAttempted': 0,
#       'twoPointersMade': 0,
#       'twoPointersPercentage': 0.0},
#      'name': 'Chima Moneke',
#      'nameI': 'C. Moneke',
#      'firstName': 'Chima',
#      'familyName': 'Moneke'}],
#    'statistics': {'assists': 24,
#     'assistsTurnoverRatio': 1.5,
#     'benchPoints': 31,
#     'biggestLead': 7,
#     'biggestLeadScore': '16-9',
#     'biggestScoringRun': 9,
#     'biggestScoringRunScore': '35-34',
#     'blocks': 4,
#     'blocksReceived': 8,
#     'fastBreakPointsAttempted': 16,
#     'fastBreakPointsMade': 7,
#     'fastBreakPointsPercentage': 0.4375,
#     'fieldGoalsAttempted': 96,
#     'fieldGoalsEffectiveAdjusted': 0.484375,
#     'fieldGoalsMade': 39,
#     'fieldGoalsPercentage': 0.40625,
#     'foulsOffensive': 0,
#     'foulsDrawn': 18,
#     'foulsPersonal': 18,
#     'foulsTeam': 18,
#     'foulsTechnical': 0,
#     'foulsTeamTechnical': 0,
#     'freeThrowsAttempted': 15,
#     'freeThrowsMade': 15,
#     'freeThrowsPercentage': 1.0,
#     'leadChanges': 11,
#     'minutes': 'PT240M00.00S',
#     'minutesCalculated': 'PT240M',
#     'points': 108,
#     'pointsAgainst': 118,
#     'pointsFastBreak': 17,
#     'pointsFromTurnovers': 7,
#     'pointsInThePaint': 44,
#     'pointsInThePaintAttempted': 44,
#     'pointsInThePaintMade': 22,
#     'pointsInThePaintPercentage': 0.5,
#     'pointsSecondChance': 11,
#     'reboundsDefensive': 33,
#     'reboundsOffensive': 14,
#     'reboundsPersonal': 47,
#     'reboundsTeam': 6,
#     'reboundsTeamDefensive': 1,
#     'reboundsTeamOffensive': 5,
#     'reboundsTotal': 53,
#     'secondChancePointsAttempted': 15,
#     'secondChancePointsMade': 3,
#     'secondChancePointsPercentage': 0.2,
#     'steals': 7,
#     'threePointersAttempted': 43,
#     'threePointersMade': 15,
#     'threePointersPercentage': 0.348837209302326,
#     'timeLeading': 'PT11M47.00S',
#     'timesTied': 8,
#     'trueShootingAttempts': 102.6,
#     'trueShootingPercentage': 0.5263157894736841,
#     'turnovers': 15,
#     'turnoversTeam': 1,
#     'turnoversTotal': 16,
#     'twoPointersAttempted': 53,
#     'twoPointersMade': 24,
#     'twoPointersPercentage': 0.45283018867924496}}}}

# %% [markdown]
# ## Close Game

# %%
def close_game

# %%
gameClock = "PT06M51.00S"

#minutes = re.search('PT[0-9][0-9]', gameClock).group().replace("PT","")

times = re.findall('[0-9][0-9]', gameClock)

seconds_in_quarter = 60*int(times[0]) + int(times[1]) + int(times[2])/100

print(seconds_in_quarter)
# Out:
# 411.0

# %%
games.get_dict()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 games.get_dict()
#
# NameError: name 'games' is not defined
